# %%
with open ('teest.txt', 'w') as file:
    file.write('5\n')
    file.write('5.55\n')
    file.write('Hi, what do you say?\n')
    file.write('[4, 5, 6]\n')
    file.write('{"name": "Olga", "age": 30}\n')

# %%
with open ('teest.txt', 'r') as file:
    teest = file.read()
print(teest)
# Out:
# 5
# 5.55
# Hi, what do you say?
# [4, 5, 6]
# {"name": "Olga", "age": 30}

# %%
a = 5
b = 5,55
c = 'Hi, what do you say?'
d = [14, 45, 65]
e = {"name": "Olga", "age": 30}
f = sum(d)/len(d)
print ('среднее значение:', f)
g = int('678')
print ('текст в целое число', g)
h = str(b)
print ('число в строку', h)
r = float(a)
print ('целое число в число с плавающей точкой', r)
# Out:
# среднее значение: 41.333333333333336
# текст в целое число 678
# число в строку (5, 55)
# целое число в число с плавающей точкой 5.0

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [3, 6, 7, 0, 9]
plt.plot (x, y)
plt.xlabel ('клиент')
plt.ylabel ('карта')
plt.title ('банк')
plt.show()
